# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline 

train = pd.read_csv("output/sorted_train0310.csv")
test = pd.read_csv("output/sorted_test0310.csv")
val = pd.read_csv("output/sorted_val0310.csv")

# %%
# Define function to calculate the relative time to a default
from datetime import datetime

def calculate_days_to_default(approval, chargeoff, terms):
    # No default occurred, return TermInMonths in days
    if pd.isnull(chargeoff):
        return terms / 12 * 365
    
    d1 = datetime.strptime(approval.split()[0], "%Y-%m-%d")
    d2 = datetime.strptime(chargeoff.split()[0], "%Y-%m-%d")
    return (d2 - d1).days

def add_relative_time_col(df):
    DaysToDefault = []
    for index, row in df.iterrows():
        approval = row["ApprovalDate"]
        chargeoff = row["ChargeOffDate"]
        terms = row['TermInMonths']
        DaysToDefault.append(calculate_days_to_default(approval, chargeoff, terms))

    df['DaysToDefault'] = pd.Series(DaysToDefault).values

    # Remove ApprovalDate, ChargeOffDate -- we no longer need these columns
#     df = df.drop(columns=["ApprovalDate", "ChargeOffDate"])

    # Convert True/False to 0/1s for Default? column
    df['Default?'] = df['LoanStatus']=='CHGOFF'
    df['Default?'] = df['Default?'].astype(int)
    return df

# %%
train = add_relative_time_col(train)
# train.columns.tolist()

val = add_relative_time_col(val)
# val.columns.tolist()
test = add_relative_time_col(test)

# %%
# filtering for the columns you don't want to include for your model
c = train.columns.tolist()
c.remove('LoanStatus')
c.remove('ChargeOffDate')
c.remove('GrossChargeOffAmount')
c.remove('BorrZip')
c.remove('CDC_Zip')
c.remove('BorrCity')

c.remove('BorrState')
c.remove('CDC_State')
c.remove('ThirdPartyLender_State')
c.remove('ProjectState')

c.remove('CDC_City')
c.remove('ProjectCounty')
c.remove('ThirdPartyLender_City')
c.remove('ApprovalDate')
# c.remove('DaysToDefault')
# c.remove('Default?')
print c
# Out:
# ['ApprovalFiscalYear', 'DeliveryMethod', 'subpgmdesc', 'TermInMonths', 'BusinessType', 'SP500_Yearly_Return', 'CPI', 'Log_GrossApproval_Norm', 'Log_HPI_Norm', 'ThirdPartyDollars_Norm', 'TermMultipleYear', 'RepeatBorrower', 'BankStateneqBorrowerState', 'ProjectStateneqBorrowerState', '2DigitNaics', 'DaysToDefault', 'Default?']

# %%
x_train = train[c]
x_train = pd.get_dummies(x_train)
print x_train.shape
x_val = val[c]
x_val = pd.get_dummies(x_val)
print x_val.shape
x_test = test[c]
x_test = pd.get_dummies(x_test)
print x_test.shape
# Out:
# (43845, 48)
# (5481, 47)
# (5481, 25)

# %%
# hazard rate model on all loan samples
from lifelines import CoxPHFitter
cph1 = CoxPHFitter()
cph1.fit(x_train, duration_col='DaysToDefault', event_col='Default?')
# Out:
# <lifelines.CoxPHFitter: fitted with 43845 observations, 38509 censored>

# %%
cph1.plot()

# %%
p = cph1.predict_survival_function(x_train[10:14].drop(['DaysToDefault','Default?'], axis = 1))
plt.xlabel('Age(days)')
plt.ylabel('Survival Probability')
plt.plot(p)
# Out:
# [<matplotlib.lines.Line2D at 0x1a176f8790>,
#  <matplotlib.lines.Line2D at 0x1a16b5b4d0>,
#  <matplotlib.lines.Line2D at 0x1a16b5b8d0>,
#  <matplotlib.lines.Line2D at 0x1a17716910>]

# %%
cph1.print_summary()
# Out:
# n=43845, number of events=5336
#
#                                                          coef  exp(coef)      se(coef)       z      p     lower 0.95    upper 0.95
# ApprovalFiscalYear                                     0.2286     1.2569        0.0120 19.0820 0.0000         0.2051        0.2521  ***
# TermInMonths                                          -0.0028     0.9972        0.0005 -5.3293 0.0000        -0.0038       -0.0018  ***
# SP500_Yearly_Return                                   -0.6363     0.5293        0.1071 -5.9395 0.0000        -0.8462       -0.4263  ***
# CPI                                                   -0.2779     0.7574        0.4902 -0.5668 0.5708        -1.2386        0.6829
# Log_GrossApproval_Norm                                 0.0309     1.0313        0.0153  2.0174 0.0437         0.0009        0.0608    *
# Log_HPI_Norm                                          -0.1281     0.8797        0.0198 -6.4588 0.0000        -0.1670       -0.0892  ***
# ThirdPartyDollars_Norm                                 0.0909     1.0952        0.0010 92.8481 0.0000         0.0890        0.0928  ***
# TermMultipleYear                                      -0.1770     0.8378        0.2800 -0.6321 0.5273        -0.7258        0.3718
# RepeatBorrower                                        -0.2186     0.8036        0.0609 -3.5926 0.0003        -0.3379       -0.0993  ***
# BankStateneqBorrowerState                              0.3073     1.3597        0.0576  5.3362 0.0000         0.1944        0.4201  ***
# ProjectStateneqBorrowerState                          -0.2862     0.7511        0.2446 -1.1699 0.2420        -0.7656        0.1933
# DeliveryMethod_504                                     1.4211     4.1418   346548.7338  0.0000 1.0000   -679221.6160   679224.4582
# DeliveryMethod_ALP                                     1.2936     3.6460   346322.1397  0.0000 1.0000   -678777.6272   678780.2145
# DeliveryMethod_PCLP                                -9014.1144     0.0000 11634754.2380 -0.0008 0.9994 -22812713.3899 22794685.1611
# subpgmdesc_Sec. 504 - Delta loans, funded 9/26/95      4.6398   103.5280           nan     nan    nan            nan           nan
# subpgmdesc_Sec. 504 - Loan Guarantees - Private...     4.8168   123.5717           nan     nan    nan            nan           nan
# subpgmdesc_Sec. 504 - Premier Certified Lender ...  9019.8900        inf 11618093.5530  0.0008 0.9994 -22762025.0429 22780064.8229
# BusinessType_CORPORATION                               0.7608     2.1401           nan     nan    nan            nan           nan
# BusinessType_INDIVIDUAL                                0.9026     2.4660           nan     nan    nan            nan           nan
# BusinessType_PARTNERSHIP                               0.6071     1.8352           nan     nan    nan            nan           nan
# 2DigitNaics_11                                        -0.5448     0.5800           nan     nan    nan            nan           nan
# 2DigitNaics_21                                        -0.3550     0.7012           nan     nan    nan            nan           nan
# 2DigitNaics_22                                        -2.2331     0.1072           nan     nan    nan            nan           nan
# 2DigitNaics_23                                        -0.4002     0.6702           nan     nan    nan            nan           nan
# 2DigitNaics_31                                        -0.5782     0.5609           nan     nan    nan            nan           nan
# 2DigitNaics_32                                        -0.4429     0.6422           nan     nan    nan            nan           nan
# 2DigitNaics_33                                        -0.6610     0.5163           nan     nan    nan            nan           nan
# 2DigitNaics_42                                        -0.8055     0.4469           nan     nan    nan            nan           nan
# 2DigitNaics_44                                        -0.2442     0.7833           nan     nan    nan            nan           nan
# 2DigitNaics_45                                        -0.5233     0.5926           nan     nan    nan            nan           nan
# 2DigitNaics_48                                        -0.9251     0.3965           nan     nan    nan            nan           nan
# 2DigitNaics_49                                        -0.9890     0.3719           nan     nan    nan            nan           nan
# 2DigitNaics_51                                        -0.6052     0.5460           nan     nan    nan            nan           nan
# 2DigitNaics_52                                        -0.0195     0.9807           nan     nan    nan            nan           nan
# 2DigitNaics_53                                         0.0368     1.0374           nan     nan    nan            nan           nan
# 2DigitNaics_54                                        -0.9736     0.3777           nan     nan    nan            nan           nan
# 2DigitNaics_55                                        -0.4671     0.6268           nan     nan    nan            nan           nan
# 2DigitNaics_56                                        -0.8287     0.4366           nan     nan    nan            nan           nan
# 2DigitNaics_61                                        -0.6407     0.5269           nan     nan    nan            nan           nan
# 2DigitNaics_62                                        -0.8777     0.4157           nan     nan    nan            nan           nan
# 2DigitNaics_71                                         0.1054     1.1112           nan     nan    nan            nan           nan
# 2DigitNaics_72                                         0.0485     1.0497           nan     nan    nan            nan           nan
# 2DigitNaics_81                                        -0.3557     0.7007           nan     nan    nan            nan           nan
# 2DigitNaics_92                                        -1.6202     0.1979           nan     nan    nan            nan           nan
# 2DigitNaics_99                                        -1.6006     0.2018           nan     nan    nan            nan           nan
# 2DigitNaics_MI                                        -0.1737     0.8405           nan     nan    nan            nan           nan
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Concordance = 0.772

# %%
print cph1.hazards_

print cph1._log_likelihood

# cph1._hessian_

# cph1._score_

cph1.baseline_hazard_.plot()
# Out:
#       ApprovalFiscalYear  TermInMonths  SP500_Yearly_Return       CPI  \
# coef            0.228611     -0.002799            -0.636254 -0.277854
#
#       Log_GrossApproval_Norm  Log_HPI_Norm  ThirdPartyDollars_Norm  \
# coef                0.030854     -0.128126                 0.09092
#
#       TermMultipleYear  RepeatBorrower  BankStateneqBorrowerState  \
# coef         -0.177005       -0.218619                   0.307274
#
#            ...        2DigitNaics_55  2DigitNaics_56  2DigitNaics_61  \
# coef       ...             -0.467073       -0.828726       -0.640733
#
#       2DigitNaics_62  2DigitNaics_71  2DigitNaics_72  2DigitNaics_81  \
# coef       -0.877679        0.105422        0.048507       -0.355691
#
#       2DigitNaics_92  2DigitNaics_99  2DigitNaics_MI
# coef        -1.62019       -1.600649       -0.173745
#
# [1 rows x 46 columns]
# -54219.1465634

# %%
# call this if want to test accuracy on val and test dataset

# to get consistent feature dimensions for both train and test dataset
def add_missing_dummy_columns(d1, d2):
    missing_cols = set(d1.columns) - set(d2.columns)
    for c in missing_cols:
        d2[c] = 0
    return d2

print 'before fix columns: '
print x_train.shape
print x_test.shape

def fix_columns(x_train, x_test):  

    x_test = add_missing_dummy_columns(x_train, x_test)

    extra_cols = set(x_test.columns) - set(x_train.columns)
    x_test = x_test[x_train.columns]
    return x_test

x_test = fix_columns(x_train, x_test)
x_val = fix_columns(x_train, x_val)
print 'after fix columns: '
print x_test.shape
print x_val.shape
# Out:
# before fix columns:
# (43845, 48)
# (5481, 25)
# after fix columns:
# (5481, 48)
# (5481, 48)

# %%
# predicting defaults using ROC curves and AUC
# y axis = true positive rate = recall = sensitivity = 
# measures the proportion of positives that are correctly identified as such
# true positive rate = # of defaults predicted that are actually defaults(TPs) / total number of defaults
# x axis = false positive rate = # of false positives / total number of negatives = 
# FPR = # of falsely predicted defaults(PIF that are predicted to be defaults) / total number of PIFs
# let thre be the thre of predicting defaults, since hazard model gives prob of survival, 1-score is the prob of default
from sklearn import metrics

def get_roc(scores, labels):
    num_defaults = sum(labels)
    num_PIF = len(labels) - num_defaults
    tpr_res = []
    fpr_res = []
    thre = np.arange(0, 1, 0.01)
    # dictionary with key = threshold and value = pair of (tpr, fpr)
    for t in thre:
        tp = fp = 0
        for idx, val in enumerate(scores):
            if 1 - val > t:
                # predict default
                if int(labels[idx]) == 1: 
                    tp += 1
                else:
                    fp += 1
        tpr = float(tp) / num_defaults
        fpr = float(fp) / num_PIF
        print 'score is', 
        print 'calculating fpr tpr for threshold: ', t,'tpr is: ', tpr, 'fpr is', fpr
        print 'tp is ', tp, 'fp is', fp 
        tpr_res.append(tpr)
        fpr_res.append(fpr)
    roc_auc = metrics.auc(fpr_res, tpr_res)
    print 'calculating auc is: ', roc_auc
    return tpr_res, fpr_res, thre, roc_auc

import matplotlib.pyplot as plt

def plot_roc(tpr, fpr, thre, roc_auc):
    plt.title('Receiver Operating Characteristics')
    plt.plot(tpr, fpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend()
    plt.plot([0,1],[0,1],'r--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.show()

# %%
# calculates predicted survival probability of given X's at its terminmonths age.
# after fitting the cph hazard model on x_train
# call get_score(x_train, cph), which calculates survival probability of each sample in x at the end of its age
# once obtained survival probability - can call get_roc curve

def search(days, dist, thre):
    # find the prob that corresponds to the days
    if days > dist[-1][0]: 
        return dist[-1][1]
    l = 0
    r = len(dist)-1
    while l < r and r > 0 and l < len(dist)-1:
        mid = l + (r - l)/2
        if abs(int(dist[mid][0]) - days) < thre:
            return dist[mid][1]
        elif int(dist[mid][0]) < days:
            l = mid + 1
        else:
            r = mid - 1

def get_scores(x_train, cph):
    scores = []

    for i in range(len(x_train) - 1):
        if i%1000 == 0: print 'finished getting scores for %d samples' % i
        i = 1
        days = x_train['TermInMonths'].loc[i] * 30
        t = cph.predict_survival_function(x_train[i:i+1].drop(['DaysToDefault','Default?'], axis = 1))
        idx = np.array(t.index.tolist())
        val = np.array(t.values.tolist())
        idx = np.reshape(idx, (len(idx), 1))
        dist = np.concatenate((idx, val), axis=1) # [days, prob]
        survival_prob = search(days, dist, 100)
        scores.append(survival_prob)

    return scores

# %%
# scores = get_scores(x_train, cph1)
# print scores
tpr, fpr, thre, roc_auc = get_roc(scores, x_train['Default?'].values.tolist())
plot_roc(tpr, fpr, thre, roc_auc)
# Out:
# finished getting scores for 0 samples
# finished getting scores for 100 samples
# finished getting scores for 200 samples
# finished getting scores for 300 samples
# finished getting scores for 400 samples
# finished getting scores for 500 samples
# finished getting scores for 600 samples
# finished getting scores for 700 samples
# finished getting scores for 800 samples
# finished getting scores for 900 samples
# finished getting scores for 1000 samples
# finished getting scores for 1100 samples
# finished getting scores for 1200 samples
# finished getting scores for 1300 samples
# finished getting scores for 1400 samples
# finished getting scores for 1500 samples
# finished getting scores for 1600 samples
# finished getting scores for 1700 samples
# finished getting scores for 1800 samples
# finished getting scores for 1900 samples
# finished getting scores for 2000 samples
# finished getting scores for 2100 samples
# finished getting scores for 2200 samples
# finished getting scores for 2300 samples
# finished getting scores for 2400 samples
# finished getting scores for 2500 samples
# finished getting scores for 2600 samples
# finished getting scores for 2700 samples
# finished getting scores for 2800 samples
# finished getting scores for 2900 samples
# finished getting scores for 3000 samples
# finished getting scores for 3100 samples
# finished getting scores for 3200 samples
# finished getting scores for 3300 samples
# finished getting scores for 3400 samples
# finished getting scores for 3500 samples
# finished getting scores for 3600 samples
# finished getting scores for 3700 samples
# finished getting scores for 3800 samples
# finished getting scores for 3900 samples
# finished getting scores for 4000 samples
# finished getting scores for 4100 samples
# finished getting scores for 4200 samples
# finished getting scores for 4300 samples
# finished getting scores for 4400 samples
# finished getting scores for 4500 samples
# finished getting scores for 4600 samples
# finished getting scores for 4700 samples
# finished getting scores for 4800 samples
# finished getting scores for 4900 samples
# finished getting scores for 5000 samples
# finished getting scores for 5100 samples
# finished getting scores for 5200 samples
# finished getting scores for 5300 samples
# finished getting scores for 5400 samples
# finished getting scores for 5500 samples
# finished getting scores for 5600 samples
# finished getting scores for 5700 samples
# finished getting scores for 5800 samples
# finished getting scores for 5900 samples
# finished getting scores for 6000 samples
# finished getting scores for 6100 samples
# finished getting scores for 6200 samples
# finished getting scores for 6300 samples
# finished getting scores for 6400 samples
# finished getting scores for 6500 samples
# finished getting scores for 6600 samples
# finished getting scores for 6700 samples
# finished getting scores for 6800 samples
# finished getting scores for 6900 samples
# finished getting scores for 7000 samples
# finished getting scores for 7100 samples
# finished getting scores for 7200 samples
# finished getting scores for 7300 samples
# finished getting scores for 7400 samples
# finished getting scores for 7500 samples
# finished getting scores for 7600 samples
# finished getting scores for 7700 samples
# finished getting scores for 7800 samples
# finished getting scores for 7900 samples
# finished getting scores for 8000 samples
# finished getting scores for 8100 samples
# finished getting scores for 8200 samples
# finished getting scores for 8300 samples
# finished getting scores for 8400 samples
# finished getting scores for 8500 samples
# finished getting scores for 8600 samples
# finished getting scores for 8700 samples
# finished getting scores for 8800 samples
# finished getting scores for 8900 samples
# finished getting scores for 9000 samples
# finished getting scores for 9100 samples
# finished getting scores for 9200 samples
# finished getting scores for 9300 samples
# finished getting scores for 9400 samples
# finished getting scores for 9500 samples
# finished getting scores for 9600 samples
# finished getting scores for 9700 samples
# finished getting scores for 9800 samples
# finished getting scores for 9900 samples
# finished getting scores for 10000 samples
# finished getting scores for 10100 samples
# finished getting scores for 10200 samples
# finished getting scores for 10300 samples
# finished getting scores for 10400 samples
# finished getting scores for 10500 samples
# finished getting scores for 10600 samples
# finished getting scores for 10700 samples
# finished getting scores for 10800 samples
# finished getting scores for 10900 samples
# finished getting scores for 11000 samples
# finished getting scores for 11100 samples
# finished getting scores for 11200 samples
# finished getting scores for 11300 samples
# finished getting scores for 11400 samples
# finished getting scores for 11500 samples
# finished getting scores for 11600 samples
# finished getting scores for 11700 samples
# finished getting scores for 11800 samples
# finished getting scores for 11900 samples
# finished getting scores for 12000 samples
# finished getting scores for 12100 samples
# finished getting scores for 12200 samples
# finished getting scores for 12300 samples
# finished getting scores for 12400 samples
# finished getting scores for 12500 samples
# finished getting scores for 12600 samples
# finished getting scores for 12700 samples
# finished getting scores for 12800 samples
# finished getting scores for 12900 samples
# finished getting scores for 13000 samples
# finished getting scores for 13100 samples
# finished getting scores for 13200 samples
# finished getting scores for 13300 samples
# finished getting scores for 13400 samples
# finished getting scores for 13500 samples
# finished getting scores for 13600 samples
# finished getting scores for 13700 samples
# finished getting scores for 13800 samples
# finished getting scores for 13900 samples
# finished getting scores for 14000 samples
# finished getting scores for 14100 samples
# finished getting scores for 14200 samples
# finished getting scores for 14300 samples
# finished getting scores for 14400 samples
# finished getting scores for 14500 samples
# finished getting scores for 14600 samples
# finished getting scores for 14700 samples
# finished getting scores for 14800 samples
# finished getting scores for 14900 samples
# finished getting scores for 15000 samples
# finished getting scores for 15100 samples
# finished getting scores for 15200 samples
# finished getting scores for 15300 samples
# finished getting scores for 15400 samples
# finished getting scores for 15500 samples
# finished getting scores for 15600 samples
# finished getting scores for 15700 samples
# finished getting scores for 15800 samples
# finished getting scores for 15900 samples
# finished getting scores for 16000 samples
# finished getting scores for 16100 samples
# finished getting scores for 16200 samples
# finished getting scores for 16300 samples
# finished getting scores for 16400 samples
# finished getting scores for 16500 samples
# finished getting scores for 16600 samples
# finished getting scores for 16700 samples
# finished getting scores for 16800 samples
# finished getting scores for 16900 samples
# finished getting scores for 17000 samples
# finished getting scores for 17100 samples
# finished getting scores for 17200 samples
# finished getting scores for 17300 samples
# finished getting scores for 17400 samples
# finished getting scores for 17500 samples
# finished getting scores for 17600 samples
# finished getting scores for 17700 samples
# finished getting scores for 17800 samples
# finished getting scores for 17900 samples
# finished getting scores for 18000 samples
# finished getting scores for 18100 samples
# finished getting scores for 18200 samples
# finished getting scores for 18300 samples
# finished getting scores for 18400 samples
# finished getting scores for 18500 samples
# finished getting scores for 18600 samples
# finished getting scores for 18700 samples
# finished getting scores for 18800 samples
# finished getting scores for 18900 samples
# finished getting scores for 19000 samples
# finished getting scores for 19100 samples
# finished getting scores for 19200 samples
# finished getting scores for 19300 samples
# finished getting scores for 19400 samples
# finished getting scores for 19500 samples
# finished getting scores for 19600 samples
# finished getting scores for 19700 samples
# finished getting scores for 19800 samples
# finished getting scores for 19900 samples
# finished getting scores for 20000 samples
# finished getting scores for 20100 samples
# finished getting scores for 20200 samples
# finished getting scores for 20300 samples
# finished getting scores for 20400 samples
# finished getting scores for 20500 samples
# finished getting scores for 20600 samples
# finished getting scores for 20700 samples
# finished getting scores for 20800 samples
# finished getting scores for 20900 samples
# finished getting scores for 21000 samples
# finished getting scores for 21100 samples
# finished getting scores for 21200 samples
# finished getting scores for 21300 samples
# finished getting scores for 21400 samples
# finished getting scores for 21500 samples
# finished getting scores for 21600 samples
# finished getting scores for 21700 samples
# finished getting scores for 21800 samples
# finished getting scores for 21900 samples
# finished getting scores for 22000 samples
# finished getting scores for 22100 samples
# finished getting scores for 22200 samples
# finished getting scores for 22300 samples
# finished getting scores for 22400 samples
# finished getting scores for 22500 samples
# finished getting scores for 22600 samples
# finished getting scores for 22700 samples
# finished getting scores for 22800 samples
# finished getting scores for 22900 samples
# finished getting scores for 23000 samples
# finished getting scores for 23100 samples
# finished getting scores for 23200 samples
# finished getting scores for 23300 samples
# finished getting scores for 23400 samples
# finished getting scores for 23500 samples
# finished getting scores for 23600 samples
# finished getting scores for 23700 samples
# finished getting scores for 23800 samples
# finished getting scores for 23900 samples
# finished getting scores for 24000 samples
# finished getting scores for 24100 samples
# finished getting scores for 24200 samples
# finished getting scores for 24300 samples
# finished getting scores for 24400 samples
# finished getting scores for 24500 samples
# finished getting scores for 24600 samples
# finished getting scores for 24700 samples
# finished getting scores for 24800 samples
# finished getting scores for 24900 samples
# finished getting scores for 25000 samples
# finished getting scores for 25100 samples
# finished getting scores for 25200 samples
# finished getting scores for 25300 samples
# finished getting scores for 25400 samples
# finished getting scores for 25500 samples
# finished getting scores for 25600 samples
# finished getting scores for 25700 samples
# finished getting scores for 25800 samples
# finished getting scores for 25900 samples
# finished getting scores for 26000 samples
# finished getting scores for 26100 samples
# finished getting scores for 26200 samples
# finished getting scores for 26300 samples
# finished getting scores for 26400 samples
# finished getting scores for 26500 samples
# finished getting scores for 26600 samples
# finished getting scores for 26700 samples
# finished getting scores for 26800 samples
# finished getting scores for 26900 samples
# finished getting scores for 27000 samples
# finished getting scores for 27100 samples
# finished getting scores for 27200 samples
# finished getting scores for 27300 samples
# finished getting scores for 27400 samples
# finished getting scores for 27500 samples
# finished getting scores for 27600 samples
# finished getting scores for 27700 samples
# finished getting scores for 27800 samples
# finished getting scores for 27900 samples
# finished getting scores for 28000 samples
# finished getting scores for 28100 samples
# finished getting scores for 28200 samples
# finished getting scores for 28300 samples
# finished getting scores for 28400 samples
# finished getting scores for 28500 samples
# finished getting scores for 28600 samples
# finished getting scores for 28700 samples
# finished getting scores for 28800 samples
# finished getting scores for 28900 samples
# finished getting scores for 29000 samples
# finished getting scores for 29100 samples
# finished getting scores for 29200 samples
# finished getting scores for 29300 samples
# finished getting scores for 29400 samples
# finished getting scores for 29500 samples
# finished getting scores for 29600 samples
# finished getting scores for 29700 samples
# finished getting scores for 29800 samples
# finished getting scores for 29900 samples
# finished getting scores for 30000 samples
# finished getting scores for 30100 samples
# finished getting scores for 30200 samples
# finished getting scores for 30300 samples
# finished getting scores for 30400 samples
# finished getting scores for 30500 samples
# finished getting scores for 30600 samples
# finished getting scores for 30700 samples
# finished getting scores for 30800 samples
# finished getting scores for 30900 samples
# finished getting scores for 31000 samples
# finished getting scores for 31100 samples
# finished getting scores for 31200 samples
# finished getting scores for 31300 samples
# finished getting scores for 31400 samples
# finished getting scores for 31500 samples
# finished getting scores for 31600 samples
# finished getting scores for 31700 samples
# finished getting scores for 31800 samples
# finished getting scores for 31900 samples
# finished getting scores for 32000 samples
# finished getting scores for 32100 samples
# finished getting scores for 32200 samples
# finished getting scores for 32300 samples
# finished getting scores for 32400 samples
# finished getting scores for 32500 samples
# finished getting scores for 32600 samples
# finished getting scores for 32700 samples
# finished getting scores for 32800 samples
# finished getting scores for 32900 samples
# finished getting scores for 33000 samples
# finished getting scores for 33100 samples
# finished getting scores for 33200 samples
# finished getting scores for 33300 samples
# finished getting scores for 33400 samples
# finished getting scores for 33500 samples
# finished getting scores for 33600 samples
# finished getting scores for 33700 samples
# finished getting scores for 33800 samples
# finished getting scores for 33900 samples
# finished getting scores for 34000 samples
# finished getting scores for 34100 samples
# finished getting scores for 34200 samples
# finished getting scores for 34300 samples
# finished getting scores for 34400 samples
# finished getting scores for 34500 samples
# finished getting scores for 34600 samples
# finished getting scores for 34700 samples
# finished getting scores for 34800 samples
# finished getting scores for 34900 samples
# finished getting scores for 35000 samples
# finished getting scores for 35100 samples
# finished getting scores for 35200 samples
# finished getting scores for 35300 samples
# finished getting scores for 35400 samples
# finished getting scores for 35500 samples
# finished getting scores for 35600 samples
# finished getting scores for 35700 samples
# finished getting scores for 35800 samples
# finished getting scores for 35900 samples
# finished getting scores for 36000 samples
# finished getting scores for 36100 samples
# finished getting scores for 36200 samples
# finished getting scores for 36300 samples
# finished getting scores for 36400 samples
# finished getting scores for 36500 samples
# finished getting scores for 36600 samples
# finished getting scores for 36700 samples
# finished getting scores for 36800 samples
# finished getting scores for 36900 samples
# finished getting scores for 37000 samples
# finished getting scores for 37100 samples
# finished getting scores for 37200 samples
# finished getting scores for 37300 samples
# finished getting scores for 37400 samples
# finished getting scores for 37500 samples
# finished getting scores for 37600 samples
# finished getting scores for 37700 samples
# finished getting scores for 37800 samples
# finished getting scores for 37900 samples
# finished getting scores for 38000 samples
# finished getting scores for 38100 samples
# finished getting scores for 38200 samples
# finished getting scores for 38300 samples
# finished getting scores for 38400 samples
# finished getting scores for 38500 samples
# finished getting scores for 38600 samples
# finished getting scores for 38700 samples
# finished getting scores for 38800 samples
# finished getting scores for 38900 samples
# finished getting scores for 39000 samples
# finished getting scores for 39100 samples
# finished getting scores for 39200 samples
# finished getting scores for 39300 samples
# finished getting scores for 39400 samples
# finished getting scores for 39500 samples
# finished getting scores for 39600 samples
# finished getting scores for 39700 samples
# finished getting scores for 39800 samples
# finished getting scores for 39900 samples
# finished getting scores for 40000 samples
# finished getting scores for 40100 samples
# finished getting scores for 40200 samples
# finished getting scores for 40300 samples
# finished getting scores for 40400 samples
# finished getting scores for 40500 samples
# finished getting scores for 40600 samples
# finished getting scores for 40700 samples
# finished getting scores for 40800 samples
# finished getting scores for 40900 samples
# finished getting scores for 41000 samples
# finished getting scores for 41100 samples
# finished getting scores for 41200 samples
# finished getting scores for 41300 samples
# finished getting scores for 41400 samples
# finished getting scores for 41500 samples
# finished getting scores for 41600 samples
# finished getting scores for 41700 samples
# finished getting scores for 41800 samples
# finished getting scores for 41900 samples
# finished getting scores for 42000 samples
# finished getting scores for 42100 samples
# finished getting scores for 42200 samples
# finished getting scores for 42300 samples
# finished getting scores for 42400 samples
# finished getting scores for 42500 samples
# finished getting scores for 42600 samples
# finished getting scores for 42700 samples
# finished getting scores for 42800 samples
# finished getting scores for 42900 samples
# finished getting scores for 43000 samples
# finished getting scores for 43100 samples
# finished getting scores for 43200 samples
# finished getting scores for 43300 samples
# finished getting scores for 43400 samples
# finished getting scores for 43500 samples
# finished getting scores for 43600 samples
# finished getting scores for 43700 samples
# finished getting scores for 43800 samples
# calculating fpr tpr for threshold:  0.0 tpr is:  1.0 fpr is 0.999974032044
# tp is  5336 fp is 38508
# calculating fpr tpr for threshold:  0.01 tpr is:  1.0 fpr is 0.999974032044
# tp is  5336 fp is 38508
# calculating fpr tpr for threshold:  0.02 tpr is:  1.0 fpr is 0.999974032044
# tp is  5336 fp is 38508
# calculating fpr tpr for threshold:  0.03 tpr is:  1.0 fpr is 0.999974032044
# tp is  5336 fp is 38508
# calculating fpr tpr for threshold:  0.04 tpr is:  1.0 fpr is 0.999974032044
# tp is  5336 fp is 38508
# calculating fpr tpr for threshold:  0.05 tpr is:  1.0 fpr is 0.999974032044
# tp is  5336 fp is 38508
# calculating fpr tpr for threshold:  0.06 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.07 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.08 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.09 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.1 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.11 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.12 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.13 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.14 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.15 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.16 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.17 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.18 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.19 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.2 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.21 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.22 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.23 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.24 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.25 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.26 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.27 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.28 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.29 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.3 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.31 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.32 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.33 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.34 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.35 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.36 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.37 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.38 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.39 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.4 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.41 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.42 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.43 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.44 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.45 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.46 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.47 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.48 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.49 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.5 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.51 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.52 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.53 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.54 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.55 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.56 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.57 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.58 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.59 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.6 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.61 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.62 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.63 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.64 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.65 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.66 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.67 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.68 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.69 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.7 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.71 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.72 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.73 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.74 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.75 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.76 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.77 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.78 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.79 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.8 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.81 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.82 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.83 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.84 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.85 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.86 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.87 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.88 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.89 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.9 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.91 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.92 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.93 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.94 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.95 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.96 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.97 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.98 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating fpr tpr for threshold:  0.99 tpr is:  0.0 fpr is 0.0
# tp is  0 fp is 0
# calculating auc is:  0.499987016022

# %%
# hazard model only on data that is death event - only on the ones that are charged off
death = train[train['LoanStatus'] == 'CHGOFF']
death = death.reset_index(drop=True)
death['Duration'] = pd.to_datetime(death['ChargeOffDate']) - pd.to_datetime(death['ApprovalDate'])
death['Observed'] = 1
death = death[c]
death.head()
# Out:
#    ApprovalFiscalYear DeliveryMethod  \
# 0                2004            ALP
# 1                2004            ALP
# 2                2005            ALP
# 3                2006            ALP
# 4                1999            504
#
#                                           subpgmdesc  TermInMonths  \
# 0  Sec. 504 - Loan Guarantees - Private Sector Fi...           240
# 1  Sec. 504 - Loan Guarantees - Private Sector Fi...           240
# 2  Sec. 504 - Loan Guarantees - Private Sector Fi...           240
# 3  Sec. 504 - Loan Guarantees - Private Sector Fi...           240
# 4  Sec. 504 - Loan Guarantees - Private Sector Fi...           240
#
#   BusinessType  SP500_Yearly_Return    CPI  Log_GrossApproval_Norm  \
# 0  CORPORATION             0.120274  0.969                0.335743
# 1  CORPORATION             0.120274  0.969                1.421916
# 2  CORPORATION             0.065440  1.040               -1.477124
# 3  CORPORATION             0.155040  1.081               -0.180838
# 4  CORPORATION             0.305258  0.887                0.286921
#
#    Log_HPI_Norm  ThirdPartyDollars_Norm  TermMultipleYear  RepeatBorrower  \
# 0      0.266927                0.480989              True               0
# 1      0.266927               -0.377884              True               0
# 2      0.454916               -0.196954              True               0
# 3      1.497527                0.170356              True               0
# 4     -0.555141               -0.377884              True               0
#
#    BankStateneqBorrowerState  ProjectStateneqBorrowerState 2DigitNaics  \
# 0                      False                         False          72
# 1                      False                         False          71
# 2                      False                         False          54
# 3                       True                         False          33
# 4                      False                         False          MI
#
#    DaysToDefault  Default?
# 0           1537         1
# 1           2977         1
# 2           1848         1
# 3           2711         1
# 4           2909         1

# %%
sum(x_train['RepeatBorrower'])
# Out:
# 2101

# %%
x_train_death = pd.get_dummies(death)

# hazard rate model on only charged off loan samples
cph2 = CoxPHFitter()
cph2.fit(x_train_death, duration_col='DaysToDefault', event_col='Default?', show_progress = True)

# cph.plot()
# Out:
# Iteration 1: norm_delta = 157.77832, step_size = 0.50000, ll = -40463.99782
# Iteration 2: norm_delta = 3.25541, step_size = 0.24875, ll = -40084.81384
# Iteration 3: norm_delta = 0.76328, step_size = 0.24751, ll = -40011.53709
# Iteration 4: norm_delta = 2.58950, step_size = 0.24627, ll = -39966.49735
# Iteration 5: norm_delta = 65.30596, step_size = 0.24504, ll = -39939.07973
# Iteration 6: norm_delta = 0.32449, step_size = 0.12191, ll = -39922.55286
# Iteration 7: norm_delta = 0.16359, step_size = 0.12130, ll = -39917.27834
# Iteration 8: norm_delta = 0.40027, step_size = 0.12069, ll = -39913.15770
# Iteration 9: norm_delta = 0.96543, step_size = 0.12009, ll = -39909.94018
# Iteration 10: norm_delta = 15.85954, step_size = 0.11949, ll = -39907.42874
# Iteration 11: norm_delta = 0.10396, step_size = 0.05944, ll = -39905.46880
# Iteration 12: norm_delta = 0.78153, step_size = 0.05915, ll = -39904.68000
# Iteration 13: norm_delta = 26.09403, step_size = 0.05885, ll = -39903.98232
# Iteration 14: norm_delta = 0.01523, step_size = 0.02928, ll = -39903.36502
# Iteration 15: norm_delta = 0.10119, step_size = 0.02913, ll = -39903.08772
# Iteration 16: norm_delta = 0.03502, step_size = 0.02899, ll = -39902.82721
# Iteration 17: norm_delta = 0.16683, step_size = 0.02884, ll = -39902.58243
# Iteration 18: norm_delta = 0.02921, step_size = 0.02870, ll = -39902.35235
# Iteration 19: norm_delta = 0.02223, step_size = 0.02855, ll = -39902.13606
# Iteration 20: norm_delta = 1.01755, step_size = 0.02841, ll = -39901.93267
# Iteration 21: norm_delta = 0.01331, step_size = 0.02827, ll = -39901.74137
# Iteration 22: norm_delta = 17.56106, step_size = 0.02813, ll = -39901.56139
# Iteration 23: norm_delta = 1.98967, step_size = 0.01399, ll = -39901.39203
# Iteration 24: norm_delta = 0.13613, step_size = 0.01392, ll = -39901.31176
# Iteration 25: norm_delta = 0.31670, step_size = 0.01385, ll = -39901.23405
# Iteration 26: norm_delta = 29.11459, step_size = 0.01378, ll = -39901.15882
# Iteration 27: norm_delta = 6.79319, step_size = 0.00686, ll = -39901.08597
# Iteration 28: norm_delta = 1.28191, step_size = 0.00682, ll = -39901.05057
# Iteration 29: norm_delta = 0.09829, step_size = 0.00679, ll = -39901.01582
# Iteration 30: norm_delta = 2.27639, step_size = 0.00676, ll = -39900.98170
# Iteration 31: norm_delta = 1.14305, step_size = 0.00672, ll = -39900.94821
# Iteration 32: norm_delta = 0.09583, step_size = 0.00669, ll = -39900.91531
# Iteration 33: norm_delta = 0.00832, step_size = 0.00665, ll = -39900.88301
# Iteration 34: norm_delta = 2.11529, step_size = 0.00662, ll = -39900.85129
# Iteration 35: norm_delta = 0.91352, step_size = 0.00659, ll = -39900.82014
# Iteration 36: norm_delta = 0.01350, step_size = 0.00656, ll = -39900.78954
# Iteration 37: norm_delta = 0.01130, step_size = 0.00652, ll = -39900.75948
# Iteration 38: norm_delta = 0.03036, step_size = 0.00649, ll = -39900.72996
# Iteration 39: norm_delta = 0.00846, step_size = 0.00646, ll = -39900.70096
# Iteration 40: norm_delta = 0.04902, step_size = 0.00643, ll = -39900.67247
# Iteration 41: norm_delta = 0.40240, step_size = 0.00639, ll = -39900.64447
# Iteration 42: norm_delta = 0.00442, step_size = 0.00636, ll = -39900.61697
# Iteration 43: norm_delta = 0.00221, step_size = 0.00633, ll = -39900.58994
# Iteration 44: norm_delta = 0.16309, step_size = 0.00630, ll = -39900.56339
# Iteration 45: norm_delta = 0.02818, step_size = 0.00627, ll = -39900.53729
# Iteration 46: norm_delta = 0.07174, step_size = 0.00623, ll = -39900.51164
# Iteration 47: norm_delta = 0.00725, step_size = 0.00620, ll = -39900.48643
# Iteration 48: norm_delta = 0.00210, step_size = 0.00617, ll = -39900.46165
# Iteration 49: norm_delta = 0.12219, step_size = 0.00614, ll = -39900.43729
# Iteration 50: norm_delta = 0.00427, step_size = 0.00611, ll = -39900.41335
# Convergence completed after 50 iterations.
# <lifelines.CoxPHFitter: fitted with 5336 observations, 0 censored>

# %%
p2 = cph2.predict_survival_function(x_train_death[10:14].drop(['DaysToDefault','Default?'], axis = 1))
plt.xlabel('Age(days)')
plt.ylabel('Survival Probability')
plt.plot(p2)
# Out:
# [<matplotlib.lines.Line2D at 0x1a17801350>,
#  <matplotlib.lines.Line2D at 0x1a17801410>,
#  <matplotlib.lines.Line2D at 0x1a178014d0>,
#  <matplotlib.lines.Line2D at 0x1a17801590>]

# %%
cph2.print_summary()
# Out:
# n=5336, number of events=5336
#
#                                                         coef                                          exp(coef)    se(coef)       z      p   lower 0.95  upper 0.95
# ApprovalFiscalYear                                    0.1387                                             1.1487      0.0125 11.0721 0.0000       0.1141      0.1632  ***
# TermInMonths                                         -0.0016                                             0.9984      0.0005 -3.0559 0.0022      -0.0026     -0.0006   **
# SP500_Yearly_Return                                  -0.2133                                             0.8079      0.1104 -1.9322 0.0533      -0.4297      0.0031    .
# CPI                                                  -0.4499                                             0.6377      0.4937 -0.9113 0.3621      -1.4176      0.5178
# Log_GrossApproval_Norm                               -0.0902                                             0.9137      0.0154 -5.8712 0.0000      -0.1204     -0.0601  ***
# Log_HPI_Norm                                          0.0670                                             1.0693      0.0203  3.3040 0.0010       0.0273      0.1067  ***
# ThirdPartyDollars_Norm                                0.0250                                             1.0253      0.0053  4.6739 0.0000       0.0145      0.0355  ***
# TermMultipleYear                                     -0.2781                                             0.7572      0.2854 -0.9743 0.3299      -0.8374      0.2813
# RepeatBorrower                                        0.0037                                             1.0037      0.0589  0.0629 0.9498      -0.1117      0.1191
# BankStateneqBorrowerState                             0.0441                                             1.0451      0.0578  0.7638 0.4450      -0.0691      0.1573
# ProjectStateneqBorrowerState                         -0.0388                                             0.9620      0.2464 -0.1573 0.8750      -0.5218      0.4442
# DeliveryMethod_504                                   -1.6253                                             0.1968         nan     nan    nan          nan         nan
# DeliveryMethod_ALP                                   -1.6394                                             0.1941         nan     nan    nan          nan         nan
# DeliveryMethod_PCLP                                -395.5073                                             0.0000         nan     nan    nan          nan         nan
# subpgmdesc_Sec. 504 - Delta loans, funded 9/26/95     1.8775                                             6.5368  43296.9297  0.0000 1.0000  -84858.5454  84862.3003
# subpgmdesc_Sec. 504 - Loan Guarantees - Private...    0.5881                                             1.8005  20951.9500  0.0000 1.0000  -41064.4793  41065.6555
# subpgmdesc_Sec. 504 - Premier Certified Lender ...  394.2194 16118712219684535235864470526977065278491221831...         nan     nan    nan          nan         nan
# BusinessType_CORPORATION                              0.5983                                             1.8190 415775.9682  0.0000 1.0000 -814905.3251 814906.5217
# BusinessType_INDIVIDUAL                               0.5798                                             1.7856 415774.1842  0.0000 1.0000 -814901.8470 814903.0065
# BusinessType_PARTNERSHIP                              0.6305                                             1.8786 415772.8090  0.0000 1.0000 -814899.1009 814900.3620
# 2DigitNaics_11                                       -1.5073                                             0.2215 428285.1303 -0.0000 1.0000 -839424.9378 839421.9233
# 2DigitNaics_21                                       -1.3832                                             0.2508 428285.1303 -0.0000 1.0000 -839424.8137 839422.0473
# 2DigitNaics_23                                       -1.7715                                             0.1701 428285.1303 -0.0000 1.0000 -839425.2020 839421.6591
# 2DigitNaics_31                                       -1.6807                                             0.1863 428285.1303 -0.0000 1.0000 -839425.1112 839421.7499
# 2DigitNaics_32                                       -1.7483                                             0.1741 428285.1303 -0.0000 1.0000 -839425.1789 839421.6822
# 2DigitNaics_33                                       -1.8130                                             0.1632 428285.1303 -0.0000 1.0000 -839425.2436 839421.6175
# 2DigitNaics_42                                       -1.7900                                             0.1670 428285.1303 -0.0000 1.0000 -839425.2205 839421.6406
# 2DigitNaics_44                                       -1.6872                                             0.1850 428285.1303 -0.0000 1.0000 -839425.1177 839421.7433
# 2DigitNaics_45                                       -1.6351                                             0.1949 428285.1303 -0.0000 1.0000 -839425.0656 839421.7955
# 2DigitNaics_48                                       -1.8652                                             0.1549 428285.1303 -0.0000 1.0000 -839425.2958 839421.5653
# 2DigitNaics_49                                       -1.4403                                             0.2369 428285.1303 -0.0000 1.0000 -839424.8709 839421.9902
# 2DigitNaics_51                                       -1.7114                                             0.1806 428285.1303 -0.0000 1.0000 -839425.1420 839421.7191
# 2DigitNaics_52                                       -1.6423                                             0.1935 428285.1303 -0.0000 1.0000 -839425.0729 839421.7882
# 2DigitNaics_53                                       -1.6867                                             0.1851 428285.1303 -0.0000 1.0000 -839425.1173 839421.7438
# 2DigitNaics_54                                       -1.8123                                             0.1633 428285.1303 -0.0000 1.0000 -839425.2428 839421.6182
# 2DigitNaics_55                                       -1.3589                                             0.2570 428285.1303 -0.0000 1.0000 -839424.7894 839422.0717
# 2DigitNaics_56                                       -1.8910                                             0.1509 428285.1303 -0.0000 1.0000 -839425.3216 839421.5395
# 2DigitNaics_61                                       -1.9790                                             0.1382 428285.1303 -0.0000 1.0000 -839425.4095 839421.4516
# 2DigitNaics_62                                       -1.8808                                             0.1525 428285.1303 -0.0000 1.0000 -839425.3114 839421.5497
# 2DigitNaics_71                                       -1.7570                                             0.1726 428285.1303 -0.0000 1.0000 -839425.1875 839421.6736
# 2DigitNaics_72                                       -1.7092                                             0.1810 428285.1303 -0.0000 1.0000 -839425.1397 839421.7214
# 2DigitNaics_81                                       -1.8414                                             0.1586 428285.1303 -0.0000 1.0000 -839425.2720 839421.5891
# 2DigitNaics_MI                                       -1.6573                                             0.1907 428285.1303 -0.0000 1.0000 -839425.0878 839421.7733
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Concordance = 0.620

# %%
# cph.hazards_

# cph._log_likelihood

# cph._hessian_

cph._score_

cph2.baseline_hazard_.plot()
