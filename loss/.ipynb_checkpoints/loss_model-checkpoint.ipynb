# %%
# Import relevant libraries
from scipy import stats
import scipy as sp
import pandas as pd
import numpy as np
import random

# %matplotlib inline
import matplotlib 
import matplotlib.pyplot as plt

# Set seed for any random operations
random.seed(1)

# %%
# Read in train dataset from hazard model pre-processing because we want the duration instead of gross approval date
# (TODO: replace with final train data.)
train_data = pd.read_csv("hazard_train.csv")
print "Number of train points:", train_data.shape[0]

# Only want defaulted loans
train_data = train_data.loc[train_data['Default?'] == 1]
print "Number of defaulted train points:", train_data.shape[0]

train_data.head()
# Out:
# Number of train points: 43845
# Number of defaulted train points: 5333
#     Unnamed: 0                        BorrName                    BorrStreet  \
# 1        82447                     HOLIDAY INN            2640 N CHERRY ROAD
# 16       39886             THE SPOT RESTAURANT         45 NORTH OCOEE STREET
# 24        5311               TECH BUILDERS INC              200 SOUTH TRAVIS
# 38       58205  MATTHEWS AUTOMOTIVE SUPER SHOP            1444 VISTA VIEW DR
# 50       65971  BURGOS MEDICAL ASSOCIATES, LLC  3063,3065,3067,3069 &3071 MI
#
#      BorrCity BorrState  BorrZip                        CDC_Name  \
# 1   ROCK HILL        SC    29730  Certified Development Corporat
# 16  CLEVELAND        TN    37311              Brightbridge, Inc.
# 24   AMARILLO        TX  MISSING  Texas Panhandle Regional Devel
# 38   LONGMONT        CO    80504  Denver Urban Economic Developm
# 50  KISSIMMEE        FL    34744   Florida First Capital Finance
#
#                     CDC_Street     CDC_City CDC_State  \
# 1   111 Executive Center Drive     Columbia        SC
# 16            535 Chestnut St.  Chattanooga        TN
# 24          801 South Fillmore     Amarillo        TX
# 38        140 East 19th Avenue       Denver        CO
# 50             1351 N. Gadsden  Tallahassee        FL
#
#               ...            ProjectState BusinessType LoanStatus  \
# 1             ...                      SC  CORPORATION     CHGOFF
# 16            ...                      TN  CORPORATION     CHGOFF
# 24            ...                      TX  CORPORATION     CHGOFF
# 38            ...                      CO  CORPORATION     CHGOFF
# 50            ...                      FL  CORPORATION     CHGOFF
#
#           ChargeOffDate  GrossChargeOffAmount  Default?  \
# 1   2010-09-08 00:00:00             1228386.0      True
# 16  2006-11-28 00:00:00               92099.0      True
# 24  1998-03-19 00:00:00                   0.0      True
# 38  2008-08-20 00:00:00              282068.0      True
# 50  2011-09-13 00:00:00              627159.0      True
#
#    ThirdPartyDollars_Norm  GrossApproval_Norm TermInMonths_Norm  \
# 1            1.853541e+00            2.697379          0.237443
# 16          -2.265977e-16           -0.894445          0.237443
# 24          -2.265977e-16           -1.133063          0.237443
# 38          -5.221134e-01           -0.068702          0.237443
# 50           2.772197e-01            1.005077          0.237443
#
#    GrossChargeOffAmount_Norm
# 1                   6.981681
# 16                  0.298004
# 24                 -0.243725
# 38                  1.415408
# 50                  3.445244
#
# [5 rows x 34 columns]

# %%
# Create new column with just loss ratio
loss_ratios = []
for index, row in train_data.iterrows():
    loss_ratio = row['GrossChargeOffAmount'] / row['GrossApproval']
    if loss_ratio >= 1.0:    # Cap at 1.0 because it doesn't really make sense to lose more than what was loaned
        loss_ratio = 1.0
    loss_ratios.append(loss_ratio)

train_data['LossRatio'] = pd.Series(loss_ratios).values
train_data['LossRatio'] = train_data['LossRatio'].astype(float)
train_data = train_data.drop(columns=["GrossChargeOffAmount"])

# %%
from pandas.core import datetools
import statsmodels.api as sm

#  Split the explanatory variables and the variable we want to predict
X = train_data.drop(columns=['LossRatio'])
Y = train_data[['LossRatio']].copy()

# Fit to a baseline linear regression model
model = sm.OLS(Y, X).fit()

# Print out the statistics
model.summary()

# Make predictions
predictions = model.predict(X)

# %%
# LINK: https://towardsdatascience.com/simple-and-multiple-linear-regression-in-python-c928425168f9

# %%
# NOTE: When this is a good model, move this code into the other loss notebook in order to run 
# everything to completion
