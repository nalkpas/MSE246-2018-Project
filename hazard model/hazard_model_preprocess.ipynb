# %%
# Import relevant libraries
import pandas as pd
import numpy as np
import random

# Set seed for any random operations
random.seed(1)

# %%
# Read in train dataset
train_data = pd.read_csv("train.csv")

# %%
# What's the size of our dataset?
print "Number of samples:", train_data.shape[0]

# Observe the first few rows.
train_data.head()
# Out:
# Number of samples: 43845
#    Unnamed: 0                        BorrName                     BorrStreet  \
# 0       66986   PSYCHIATRIC MANAGE. & COUNSEL  BEAVER BROOK OFFICE PK #B-LL/
# 1       82447                     HOLIDAY INN             2640 N CHERRY ROAD
# 2       45549  COUNTRY INNS & SUITES BY CARLS           2260 LINCOLN HIGHWAY
# 3       23121         SANYOU TECHNOLOGY, INC.              2056 BERING DRIVE
# 4       47452               COUNTRY CARE, LLC             533 SOUTH 950 WEST
#
#                          BorrCity BorrState  BorrZip  \
# 0  CHELMSFORD (CHELMSFORD CENTER)        MA  MISSING
# 1                       ROCK HILL        SC    29730
# 2                       LANCASTER        PA    17602
# 3                        SAN JOSE        CA    95131
# 4                      FARMINGTON        UT    84025
#
#                          CDC_Name                  CDC_Street        CDC_City  \
# 0  Granite State Economic Develop             One Cate Street      Portsmouth
# 1  Certified Development Corporat  111 Executive Center Drive        Columbia
# 2  South Eastern Economic Develop      737 Constitution Drive           Exton
# 3      Capital Access Group, Inc.       150 California Street   San Francisco
# 4  Mountain West Small Business F        2595 East 3300 South  Salt Lake City
#
#   CDC_State            ...            ProjectState BusinessType LoanStatus  \
# 0        NH            ...                      MA  CORPORATION        PIF
# 1        SC            ...                      SC  CORPORATION     CHGOFF
# 2        PA            ...                      PA  CORPORATION        PIF
# 3        CA            ...                      CA  CORPORATION        PIF
# 4        UT            ...                      UT  CORPORATION        PIF
#
#          ChargeOffDate  GrossChargeOffAmount  Default? ThirdPartyDollars_Norm  \
# 0                  NaN                   0.0     False          -1.192669e+00
# 1  2010-09-08 00:00:00             1228386.0      True           1.853541e+00
# 2                  NaN                   0.0     False          -2.265977e-16
# 3                  NaN                   0.0     False          -2.265977e-16
# 4                  NaN                   0.0     False          -2.265977e-16
#
#    GrossApproval_Norm TermInMonths_Norm GrossChargeOffAmount_Norm
# 0           -0.775136          0.237443                 -0.243725
# 1            2.697379          0.237443                  6.981681
# 2           -0.401511         -3.890653                 -0.243725
# 3           -0.200570          0.237443                 -0.243725
# 4           -0.404651          0.237443                 -0.243725
#
# [5 rows x 34 columns]

# %%
# Define functions to do some additional pre-processing
def label_as_categorical(df):
    df[['NaicsCode','BorrZip','CDC_Zip','ApprovalFiscalYear']] = df[['NaicsCode','BorrZip','CDC_Zip','ApprovalFiscalYear']].astype(str)
    return df
    
def drop_redundant_cols(df):
    return df.drop(columns=["Unnamed: 0", "BorrName", "BorrStreet", "NaicsDescription", "LoanStatus"])
    
def drop_norm_cols(df):
    return df.drop(columns=["GrossApproval_Norm", "TermInMonths_Norm", "GrossChargeOffAmount_Norm", "ThirdPartyDollars_Norm"])

def drop_interest_col(df):
    return df.drop(columns=["InitialInterestRate"])

# %%
# Define function to calculate the relative time to a default
from datetime import datetime

def calculate_days_to_default(approval, chargeoff, terms):
    # No default occurred, return TermInMonths in days
    if pd.isnull(chargeoff):
        return terms / 12 * 365
    
    d1 = datetime.strptime(approval.split()[0], "%Y-%m-%d")
    d2 = datetime.strptime(chargeoff.split()[0], "%Y-%m-%d")
    return (d2 - d1).days

def add_relative_time_col(df):
    DaysToDefault = []
    for index, row in df.iterrows():
        approval = row["ApprovalDate"]
        chargeoff = row["ChargeOffDate"]
        terms = row['TermInMonths']
        DaysToDefault.append(calculate_days_to_default(approval, chargeoff, terms))

    df['DaysToDefault'] = pd.Series(DaysToDefault).values

    # Remove ApprovalDate, ChargeOffDate -- we no longer need these columns
    df = df.drop(columns=["ApprovalDate", "ChargeOffDate"])

    # Convert True/False to 0/1s for Default? column
    df['Default?'] = df['Default?'].astype(int)
    return df

# %%
# Call our functions
train_data = label_as_categorical(train_data)
train_data = drop_redundant_cols(train_data)
train_data = drop_norm_cols(train_data)

train_data = add_relative_time_col(train_data)

train_data.head()
# Out:
#                          BorrCity BorrState  BorrZip  \
# 0  CHELMSFORD (CHELMSFORD CENTER)        MA  MISSING
# 1                       ROCK HILL        SC    29730
# 2                       LANCASTER        PA    17602
# 3                        SAN JOSE        CA    95131
# 4                      FARMINGTON        UT    84025
#
#                          CDC_Name                  CDC_Street        CDC_City  \
# 0  Granite State Economic Develop             One Cate Street      Portsmouth
# 1  Certified Development Corporat  111 Executive Center Drive        Columbia
# 2  South Eastern Economic Develop      737 Constitution Drive           Exton
# 3      Capital Access Group, Inc.       150 California Street   San Francisco
# 4  Mountain West Small Business F        2595 East 3300 South  Salt Lake City
#
#   CDC_State  CDC_Zip           ThirdPartyLender_Name ThirdPartyLender_City  \
# 0        NH  MISSING  Enterprise Bank and Trust Comp                LOWELL
# 1        SC  29210.0  Federal Deposit Insurance Corp            WASHINGTON
# 2        PA  19341.0                         MISSING               MISSING
# 3        CA  94111.0                         MISSING               MISSING
# 4        UT  84109.0                         MISSING               MISSING
#
#        ...      DeliveryMethod  \
# 0      ...                 ALP
# 1      ...                 504
# 2      ...                 ALP
# 3      ...                 504
# 4      ...                 504
#
#                                           subpgmdesc  TermInMonths NaicsCode  \
# 0  Sec. 504 - Loan Guarantees - Private Sector Fi...           240  624110.0
# 1  Sec. 504 - Loan Guarantees - Private Sector Fi...           240  721110.0
# 2  Sec. 504 - Loan Guarantees - Private Sector Fi...           120  721110.0
# 3  Sec. 504 - Loan Guarantees - Private Sector Fi...           240  334411.0
# 4  Sec. 504 - Loan Guarantees - Private Sector Fi...           240  623110.0
#
#   ProjectCounty ProjectState  BusinessType GrossChargeOffAmount Default?  \
# 0     MIDDLESEX           MA   CORPORATION                  0.0        0
# 1          YORK           SC   CORPORATION            1228386.0        1
# 2     LANCASTER           PA   CORPORATION                  0.0        0
# 3   SANTA CLARA           CA   CORPORATION                  0.0        0
# 4         DAVIS           UT   CORPORATION                  0.0        0
#
#   DaysToDefault
# 0          7300
# 1          1575
# 2          3650
# 3          7300
# 4          7300
#
# [5 rows x 24 columns]

# %%
# Save output before fitting model just in case
train_data.to_csv("hazard_train.csv")

# %%
# Read in test dataset
test_data = pd.read_csv("test_with_missing.csv")
test_data = label_as_categorical(test_data)
test_data = drop_redundant_cols(test_data)
test_data = drop_norm_cols(test_data)

test_data = add_relative_time_col(test_data)

test_data.to_csv("hazard_test.csv")
test_data.head()
# Out:
#             BorrCity BorrState BorrZip                        CDC_Name  \
# 0       FORT COLLINS        CO   80525   Colorado Lending Source, Ltd.
# 1             MENTOR        OH   44060  Mentor Economic Assistance Cor
# 2           SHERIDAN        CO   80223  Denver Urban Economic Developm
# 3         HUNTINGTON        NY   11746  Long Island Development Corpor
# 4  ELK GROVE VILLAGE        IL   60007              SomerCor 504, Inc.
#
#                     CDC_Street  CDC_City CDC_State  CDC_Zip  \
# 0              518 17th Street    Denver        CO  80202.0
# 1  8500 Civic Center Boulevard    Mentor        OH  44060.0
# 2         140 East 19th Avenue    Denver        CO  80203.0
# 3             45 Seaman Avenue  Bethpage        NY  11714.0
# 4        601 S. LaSalle Street   Chicago        IL  60605.0
#
#   ThirdPartyLender_Name ThirdPartyLender_City      ...      DeliveryMethod  \
# 0        Advantage Bank              LOVELAND      ...                 504
# 1               MISSING               MISSING      ...                 504
# 2               MISSING               MISSING      ...                 504
# 3               MISSING               MISSING      ...                 504
# 4               MISSING               MISSING      ...                 504
#
#                                           subpgmdesc  TermInMonths NaicsCode  \
# 0  Sec. 504 - Loan Guarantees - Private Sector Fi...           240  624410.0
# 1  Sec. 504 - Loan Guarantees - Private Sector Fi...           240   MISSING
# 2  Sec. 504 - Loan Guarantees - Private Sector Fi...           240   MISSING
# 3  Sec. 504 - Loan Guarantees - Private Sector Fi...           240   MISSING
# 4  Sec. 504 - Loan Guarantees - Private Sector Fi...           240  333514.0
#
#   ProjectCounty ProjectState  BusinessType GrossChargeOffAmount Default?  \
# 0       LARIMER           CO   CORPORATION              18174.0        1
# 1          LAKE           OH   CORPORATION                  0.0        0
# 2      ARAPAHOE           CO   CORPORATION                  0.0        0
# 3       SUFFOLK           NY   CORPORATION                  0.0        0
# 4          COOK           IL   CORPORATION                  0.0        0
#
#   DaysToDefault
# 0          1689
# 1          7300
# 2          7300
# 3          7300
# 4          7300
#
# [5 rows x 24 columns]

# %%
# Build a hazard model with the data we generated/processed in R
