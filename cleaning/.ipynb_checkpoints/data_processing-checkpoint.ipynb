# %%
# Import relevant libraries
import pandas as pd
import numpy as np
import random

# Set seed for any random operations
random.seed(1)

# First, let's open the file!
print("loading")
data = pd.read_excel("SBA_Loan_data_.xlsx", "Sheet1")
print("loaded")
# Out:
# loading
# loaded

# %%
# What's the size of our dataset?
print "Number of samples:", data.shape[0]

# Observe the first few rows.
data.head()
# Out:
# Number of samples: 147423
#    Program                        BorrName                    BorrStreet  \
# 0      504  ROBERT G. FIELDS AND MARY D. F                 55 & RICHLAND
# 1      504              CANDLELAMP COMPANY                 3454 NIKI WAY
# 2      504       NATIONAL COMPOSITES, INC.          2303 N. BENDIX DRIVE
# 3      504           WENDY'S OF HARRISBURG  OUTLOT A. TR. 45N & SMALL ST
# 4      504   RON SAUNORIS GARDEN CTR, INC.            13747 W. 159TH ST.
#
#       BorrCity BorrState  BorrZip                        CDC_Name  \
# 0  KANSAS CITY        KS    66106        Avenue Area Incorporated
# 1    RIVERSIDE        CA    92507  CDC Small Business Finance Cor
# 2   SOUTH BEND        IN    46628  Business Development Corporati
# 3   HARRISBURG        IL    62946  Small Business Growth Corporat
# 4     LOCKPORT        IL    60441            MISSNG/INACTV LENDER
#
#                    CDC_Street        CDC_City CDC_State         ...           \
# 0           3324 Emerald Lane  Jefferson City        MO         ...
# 1       2448 Historic Decatur       San Diego        CA         ...
# 2    218 W. Washington Street      South Bend        IN         ...
# 3  2401 West White Oaks Drive     Springfield        IL         ...
# 4                         NaN             NaN       NaN         ...
#
#    InitialInterestRate TermInMonths NaicsCode NaicsDescription  ProjectCounty  \
# 0                  NaN           12       NaN              NaN      WYANDOTTE
# 1                  NaN          240       NaN              NaN      RIVERSIDE
# 2                  NaN          120       NaN              NaN      ST JOSEPH
# 3                  NaN          240       NaN              NaN         SALINE
# 4                  NaN          240       NaN              NaN           WILL
#
#    ProjectState BusinessType  LoanStatus ChargeOffDate GrossChargeOffAmount
# 0            KS   INDIVIDUAL         PIF           NaT                  0.0
# 1            CA   INDIVIDUAL         PIF           NaT                  0.0
# 2            IN  CORPORATION         PIF           NaT                  0.0
# 3            IL  CORPORATION      CHGOFF    2003-03-28                  0.0
# 4            IL  CORPORATION      CANCLD           NaT                  0.0
#
# [5 rows x 30 columns]

# %%
# Observe NaN rows in borrower state
nan_state_rows = data[data['BorrState'].isnull()]
nan_state_rows
# Out:
#        Program                       BorrName                    BorrStreet  \
# 36780      504  ASSETSALE07 73X4149 FINBUSGTY                           NaN
# 78608      504       MMS LOGISTIC CORPORATION  CARR 181 KM 2.3 BARRIO CELAD
#
#       BorrCity BorrState  BorrZip                        CDC_Name  \
# 36780      NaN       NaN        0            MISSNG/INACTV LENDER
# 78608   GURABO       NaN      778  Puerto Rico Business Developme
#
#                   CDC_Street  CDC_City CDC_State         ...           \
# 36780                    NaN       NaN       NaN         ...
# 78608  Capitan Espada Street  San Juan        PR         ...
#
#        InitialInterestRate TermInMonths NaicsCode  \
# 36780                  NaN            0       NaN
# 78608                  NaN          240  484220.0
#
#                                         NaicsDescription  ProjectCounty  \
# 36780                                                NaN            NaN
# 78608  Specialized Freight (except Used Goods) Trucki...         GURABO
#
#        ProjectState BusinessType  LoanStatus ChargeOffDate  \
# 36780           NaN          NaN      EXEMPT           NaT
# 78608            PR  CORPORATION      CANCLD           NaT
#
#       GrossChargeOffAmount
# 36780                  0.0
# 78608                  0.0
#
# [2 rows x 30 columns]

# %%
# Drop bad data
data = data[data.LoanStatus != 'CANCLD']
data = data[data.LoanStatus != 'EXEMPT']

# Drop 'Program' column
data = data.drop(columns=['Program'])

# Drop NaN rows found previously
data = data.dropna(subset=['BorrState'])

# Specify that NAICS + ZIP codes and 'ApprovalFiscalYear' are categorical
data[['NaicsCode','BorrZip','CDC_Zip','ApprovalFiscalYear']] = data[['NaicsCode','BorrZip','CDC_Zip','ApprovalFiscalYear']].fillna("MISSING")
data[['NaicsCode','BorrZip','CDC_Zip','ApprovalFiscalYear']] = data[['NaicsCode','BorrZip','CDC_Zip','ApprovalFiscalYear']].astype(str)

# Fill in the empty entries under 'ChargeOffDate' with NA/not applicable
data.update(data['ChargeOffDate'].fillna("NA"))

data.head()
# Out:
#                          BorrName                    BorrStreet  \
# 0  ROBERT G. FIELDS AND MARY D. F                 55 & RICHLAND
# 1              CANDLELAMP COMPANY                 3454 NIKI WAY
# 2       NATIONAL COMPOSITES, INC.          2303 N. BENDIX DRIVE
# 3           WENDY'S OF HARRISBURG  OUTLOT A. TR. 45N & SMALL ST
# 6  ROCKY MTN EMPLOYE BENEFTS, INC                3200 S. 700 E.
#
#          BorrCity BorrState BorrZip                        CDC_Name  \
# 0     KANSAS CITY        KS   66106        Avenue Area Incorporated
# 1       RIVERSIDE        CA   92507  CDC Small Business Finance Cor
# 2      SOUTH BEND        IN   46628  Business Development Corporati
# 3      HARRISBURG        IL   62946  Small Business Growth Corporat
# 6  SALT LAKE CITY        UT   84106  Mountain West Small Business F
#
#                    CDC_Street        CDC_City CDC_State  CDC_Zip  \
# 0           3324 Emerald Lane  Jefferson City        MO  65109.0
# 1       2448 Historic Decatur       San Diego        CA  92106.0
# 2    218 W. Washington Street      South Bend        IN  46601.0
# 3  2401 West White Oaks Drive     Springfield        IL  62704.0
# 6        2595 East 3300 South  Salt Lake City        UT  84109.0
#
#            ...          InitialInterestRate TermInMonths NaicsCode  \
# 0          ...                          NaN           12   MISSING
# 1          ...                          NaN          240   MISSING
# 2          ...                          NaN          120   MISSING
# 3          ...                          NaN          240   MISSING
# 6          ...                          NaN          240   MISSING
#
#    NaicsDescription  ProjectCounty ProjectState BusinessType LoanStatus  \
# 0               NaN      WYANDOTTE           KS   INDIVIDUAL        PIF
# 1               NaN      RIVERSIDE           CA   INDIVIDUAL        PIF
# 2               NaN      ST JOSEPH           IN  CORPORATION        PIF
# 3               NaN         SALINE           IL  CORPORATION     CHGOFF
# 6               NaN      SALT LAKE           UT  CORPORATION        PIF
#
#          ChargeOffDate  GrossChargeOffAmount
# 0                   NA                   0.0
# 1                   NA                   0.0
# 2                   NA                   0.0
# 3  2003-03-28 00:00:00                   0.0
# 6                   NA                   0.0
#
# [5 rows x 29 columns]

# %%
# List the column headers
print list(data)

# Count how many unique values are in certain columns
print "Number of samples:", data.shape[0]
print "BorrName vals:", len(data['BorrName'].unique())
print "BorrStreet vals:", len(data['BorrStreet'].unique())
print "CDC_Street vals:", len(data['CDC_Street'].unique())
print "ThirdPartyLender_Name vals:", len(data['ThirdPartyLender_Name'].unique())
print "ThirdPartyLender_City vals:", len(data['ThirdPartyLender_City'].unique())
print "InitialInterestRate vals:", len(data['InitialInterestRate'].unique())
# Out:
# [u'BorrName', u'BorrStreet', u'BorrCity', u'BorrState', u'BorrZip', u'CDC_Name', u'CDC_Street', u'CDC_City', u'CDC_State', u'CDC_Zip', u'ThirdPartyLender_Name', u'ThirdPartyLender_City', u'ThirdPartyLender_State', u'ThirdPartyDollars', u'GrossApproval', u'ApprovalDate', u'ApprovalFiscalYear', u'DeliveryMethod', u'subpgmdesc', u'InitialInterestRate', u'TermInMonths', u'NaicsCode', u'NaicsDescription', u'ProjectCounty', u'ProjectState', u'BusinessType', u'LoanStatus', u'ChargeOffDate', u'GrossChargeOffAmount']
# Number of samples: 54807
# BorrName vals: 52069
# BorrStreet vals: 53511
# CDC_Street vals: 334
# ThirdPartyLender_Name vals: 2386
# ThirdPartyLender_City vals: 1582
# InitialInterestRate vals: 2

# %%
# Normalize numerical variables
def normalize_col(data, col_name):
    mean = np.nanmean(data[col_name])
    stdev = np.nanstd(data[col_name])
    if stdev != 0:
        return data[col_name].apply(lambda x: (x-mean)/stdev)
    return 0

numerics = data.select_dtypes(include=np.number)
for column in numerics.columns:
    data[column + '_Norm'] = normalize_col(data, column)
data.head()

# Fill missing numerical data with means
numerics = data.select_dtypes(include=np.number)
means = dict(zip(numerics.columns, np.nanmean(numerics,axis = 0)))
numerics = numerics.fillna(means)
data.update(numerics)

# Fill missing categorical data with a MISSING tag
cats = data.drop(columns=numerics.columns)
cats = cats.fillna("MISSING")
data.update(cats)

# Write this output
data.to_csv("output/output_with_missing.csv")

data.head()
# Out:
#                          BorrName                    BorrStreet  \
# 0  ROBERT G. FIELDS AND MARY D. F                 55 & RICHLAND
# 1              CANDLELAMP COMPANY                 3454 NIKI WAY
# 2       NATIONAL COMPOSITES, INC.          2303 N. BENDIX DRIVE
# 3           WENDY'S OF HARRISBURG  OUTLOT A. TR. 45N & SMALL ST
# 6  ROCKY MTN EMPLOYE BENEFTS, INC                3200 S. 700 E.
#
#          BorrCity BorrState BorrZip                        CDC_Name  \
# 0     KANSAS CITY        KS   66106        Avenue Area Incorporated
# 1       RIVERSIDE        CA   92507  CDC Small Business Finance Cor
# 2      SOUTH BEND        IN   46628  Business Development Corporati
# 3      HARRISBURG        IL   62946  Small Business Growth Corporat
# 6  SALT LAKE CITY        UT   84106  Mountain West Small Business F
#
#                    CDC_Street        CDC_City CDC_State  CDC_Zip  \
# 0           3324 Emerald Lane  Jefferson City        MO  65109.0
# 1       2448 Historic Decatur       San Diego        CA  92106.0
# 2    218 W. Washington Street      South Bend        IN  46601.0
# 3  2401 West White Oaks Drive     Springfield        IL  62704.0
# 6        2595 East 3300 South  Salt Lake City        UT  84109.0
#
#              ...             ProjectState BusinessType LoanStatus  \
# 0            ...                       KS   INDIVIDUAL        PIF
# 1            ...                       CA   INDIVIDUAL        PIF
# 2            ...                       IN  CORPORATION        PIF
# 3            ...                       IL  CORPORATION     CHGOFF
# 6            ...                       UT  CORPORATION        PIF
#
#          ChargeOffDate  GrossChargeOffAmount ThirdPartyDollars_Norm  \
# 0                   NA                   0.0           1.010131e-17
# 1                   NA                   0.0           1.010131e-17
# 2                   NA                   0.0           1.010131e-17
# 3  2003-03-28 00:00:00                   0.0           1.010131e-17
# 6                   NA                   0.0           1.010131e-17
#
#   GrossApproval_Norm InitialInterestRate_Norm TermInMonths_Norm  \
# 0          -0.773692                        0         -7.703101
# 1          -0.912913                        0          0.236724
# 2          -0.503773                        0         -3.942131
# 3          -0.500932                        0          0.236724
# 6          -0.807787                        0          0.236724
#
#    GrossChargeOffAmount_Norm
# 0                  -0.291126
# 1                  -0.291126
# 2                  -0.291126
# 3                  -0.291126
# 6                  -0.291126
#
# [5 rows x 34 columns]

# %%
# Remove nonsense ZIP codes
# Process a table of ZIP code ranges for each state found online
file = open("zipcodes.csv","r")
zip_ref = [line.strip().split(",") for line in file]
zip_ref = {line[2] : (int(line[3]),int(line[4])) for line in zip_ref}
# Deal with corner cases ("GU" = Guam and "VI" = Virgin Islands)
zip_ref["MISSING"] = (1,-1)
zip_ref["GU"] = (96910,96932)
zip_ref["VI"] = (801, 851)

# Make a record we can edit while iterating
zips = data[['BorrState','BorrZip','CDC_State','CDC_Zip']]

for index, series in data.iterrows():
    # Load ranges
    borr_bot, borr_top = zip_ref[series['BorrState']]
    cdc_bot, cdc_top = zip_ref[series['CDC_State']]

    # Check borrower zip code
    if(series['BorrZip'] == "MISSING"):
        borr_zip = -1
    else:
        borr_zip = float(series['BorrZip']) 
        
    # Check CDC zip code
    if(series['CDC_Zip'] == "MISSING"):
        cdc_zip = -1
    else:
        cdc_zip = float(series['CDC_Zip']) 

    # compare with ranges
    if borr_bot > borr_zip or borr_zip > borr_top:
        zips.at[index,'BorrZip'] = "MISSING"
    if borr_bot > cdc_zip or cdc_zip > borr_top:
        zips.at[index,'CDC_Zip'] = "MISSING"
data.update(zips)

data.head()

# %%
# View numerical variables
data.select_dtypes(include=np.number).head()
# Out:
#    ThirdPartyDollars  GrossApproval  InitialInterestRate  TermInMonths  \
# 0       844168.07434         166000                 3.25            12
# 1       844168.07434         117000                 3.25           240
# 2       844168.07434         261000                 3.25           120
# 3       844168.07434         262000                 3.25           240
# 6       844168.07434         154000                 3.25           240
#
#    GrossChargeOffAmount  ThirdPartyDollars_Norm  GrossApproval_Norm  \
# 0                   0.0            1.010131e-17           -0.773692
# 1                   0.0            1.010131e-17           -0.912913
# 2                   0.0            1.010131e-17           -0.503773
# 3                   0.0            1.010131e-17           -0.500932
# 6                   0.0            1.010131e-17           -0.807787
#
#    InitialInterestRate_Norm  TermInMonths_Norm  GrossChargeOffAmount_Norm
# 0                         0          -7.703101                  -0.291126
# 1                         0           0.236724                  -0.291126
# 2                         0          -3.942131                  -0.291126
# 3                         0           0.236724                  -0.291126
# 6                         0           0.236724                  -0.291126

# %%
# Save 10% as test data
shuffled = data.sample(frac=1)
test_start_index = int(round(data.shape[0] * .9))
test_data = shuffled[test_start_index:]

# Shuffle remaining rows
remaining_data = data[:test_start_index]
remaining_data = remaining_data.sample(frac=1)

# Split remaining into 80% training, 10% validation sets
validation_start_index = int(round(remaining_data.shape[0] * 8./9))
train_data = remaining_data[:validation_start_index]
validation_data = remaining_data[validation_start_index:]

print "Num rows in train:", len(train_data)
print "Num rows in test:", len(test_data)
print "Num rows in validation:", len(validation_data)

# Write test and validation set to separate outputs
test_data.to_csv("output/test_with_missing.csv")
validation_data.to_csv("output/validation_with_missing.csv")

# Drop 'InitialInterestRate' since all NaN values
train_data = train_data.drop(columns=['InitialInterestRate'])
# Out:
# Num rows in train: 43845
# Num rows in test: 5481
# Num rows in validation: 5481

# %%
# Write a copy to output
train_data.to_csv("output/train.csv")

# %%
# Compute some statistics
chargeoff_count = (train_data['ChargeOffDate'] != "NA").sum()
print 'Chargeoffs:', chargeoff_count
print 'Percentage of loans that defaulted:', float(chargeoff_count)/len(train_data)

train_data['GrossChargeOffAmount'].describe()
# Out:
# Chargeoffs: 5347
# Percentage of loans that defaulted: 0.121952332079
# count    4.384500e+04
# mean     4.101779e+04
# std      1.671377e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.279220e+06
# Name: GrossChargeOffAmount, dtype: float64

# %%
# Visualize the training data here with plots
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Histogram of chargeoff amounts (excluding zero amounts)
positive_chargeoffs = train_data['GrossChargeOffAmount'] > 0.0
sns.distplot(train_data[positive_chargeoffs]['GrossChargeOffAmount']);

# %%
# Correlation between GrossChargeOffAmount and GrossApproval
var = 'GrossApproval'
corr_data = pd.concat([train_data['GrossChargeOffAmount'], train_data[var]], axis=1)
corr_data.plot.scatter(x=var, y='GrossChargeOffAmount',rot=45);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b8e5a2cc05a0> in <module>()
#       2 var = 'GrossApproval'
#       3 corr_data = pd.concat([train_data['GrossChargeOffAmount'], train_data[var]], axis=1)
# ----> 4 corr_data.plot.scatter(x=var, y='GrossChargeOffAmount',rot=45);
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/plotting/_core.pyc in scatter(self, x, y, s, c, **kwds)
#    2853         axes : matplotlib.AxesSubplot or np.array of them
#    2854         """
# -> 2855         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    2856
#    2857     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/plotting/_core.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1900                  yerr=yerr, xerr=xerr,
#    1901                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1902                  **kwds)
#    1903
#    1904
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1685         if isinstance(data, DataFrame):
#    1686             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1687                              kind=kind, **kwds)
#    1688         else:
#    1689             raise ValueError("plot kind %r can only be used for data frames"
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __init__(self, data, x, y, s, c, **kwargs)
#     835             # the handling of this argument later
#     836             s = 20
# --> 837         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     838         if is_integer(c) and not self.data.columns.holds_integer():
#     839             c = self.data.columns[c]
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __init__(self, data, x, y, **kwargs)
#     802
#     803     def __init__(self, data, x, y, **kwargs):
# --> 804         MPLPlot.__init__(self, data, **kwargs)
#     805         if x is None or y is None:
#     806             raise ValueError(self._kind + ' requires and x and y column')
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __init__(self, data, kind, by, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, fig, title, xlim, ylim, xticks, yticks, sort_columns, fontsize, secondary_y, colormap, table, layout, **kwds)
#      98                  table=False, layout=None, **kwds):
#      99
# --> 100         _converter._WARN = False
#     101         self.data = data
#     102         self.by = by
#
# NameError: global name '_converter' is not defined

# %%
# Plot between NAICS code and GrossChargeOffAmount
var = 'BorrState'
cat_data = pd.concat([train_data['GrossChargeOffAmount'], train_data[var]], axis=1)
f, ax = plt.subplots(figsize=(12, 8))
fig = sns.boxplot(x=var, y='GrossChargeOffAmount', data=cat_data)

# %%
# Correlation matrix
corr_mat = train_data.corr()
f, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(corr_mat, vmax=.8, annot=True, square=True);
